# %% [markdown]
# # ADAT 5410 - Application and Deployment Final Project

# %% [markdown]
# # GROUP-14

# %%
1. Hemanth Sherla

2. Rohith Myana

3. Sushmitha Gangadari

4. Vivek Adharsh Veldi

# %% [markdown]
# # CARDIO-VASCULAR DISEASES PREDICTION

# %% [markdown]
# predicting wheather a person is suffering from cardio vascuar diseases or not

# %% [markdown]
# # Introduction

# %% [raw]
# 1. Our primary goals revolve around leveraging machine learning to forecast cardiovascular disease, pinpointing individuals at high risk for timely intervention.
#
# 2. Through comprehensive analysis of health data, our aim is to anticipate the onset of heart conditions, enabling swift intervention and tailored care delivery.
#
# 3. By identifying individuals susceptible to cardiovascular diseases, we can implement preventive measures and interventions, ultimately improving patient outcomes and reducing healthcare burdens.
#
# 4. Additionally, our objective includes ensuring equitable distribution of resources, addressing disparities in healthcare access, and enhancing overall healthcare delivery efficiency.
#
# 5. This holistic approach not only aids in early detection and intervention but also contributes to the broader goal of improving population health and well-being.

# %% [markdown]
# # Data Description

# %% [raw]
# The Dataset is collected from the Kaggle and it comprises various health-related attributes categorized into three types: Objective, Examination, and Subjective features.
#
# Objective features include factual information such as age, height, weight, and gender.
#
# Examination features encompass results from medical tests, including systolic and diastolic blood pressure, cholesterol levels, and glucose levels.
#
# Subjective features entail information provided by the patients themselves, such as smoking habits, alcohol intake, and physical activity levels.
#
# These attributes play a crucial role in predicting the presence or absence of cardiovascular disease, which serves as the target variable.

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sushm_8mc8bbk\\OneDrive\\Desktop\\SUSHMITHA\\ADTA\\ADTA-5340 Big Data'

# %%
#pass the location of the csv file that is stored
os.chdir("C://Users//sushm_8mc8bbk//OneDrive//Desktop//SUSHMITHA//ADTA//ADTA-5340 Big Data")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sushm_8mc8bbk\\OneDrive\\Desktop\\SUSHMITHA\\ADTA\\ADTA-5340 Big Data'

# %%
#importing dataset
df=pd.read_csv("cardiovascular_diseases.csv")

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol   gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1      1      0
# 1   1  20228       1     156    85.0    140     90            3      1      0
# 2   2  18857       1     165    64.0    130     70            3      1      0
# 3   3  17623       2     169    82.0    150    100            1      1      0
# 4   4  17474       1     156    56.0    100     60            1      1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# !!! here , age is in days not years
#
# ap_hi is systolic blood pressure
#
# ap_lo is diastolic blood pressure
#
# gluc is the persons glucose level
#
# height is in centimeters
#
# weight is in kilograms

# %%
df.shape
# Out:
# (69999, 13)

# %% [markdown]
# # Question of Interest

# %% [raw]
# 1. How do age, gender, and blood pressure (systolic and diastolic) levels correlate with the risk of cardiovascular disease?
#
# 2. Do elevated cholesterol and glucose levels significantly increase the risk of cardiovascular disease in the population?
#
# 3. How do lifestyle factors like smoking, alcohol consumption, and physical activity affect the likelihood of developing cardiovascular disease?

# %% [markdown]
# # Data Understanding

# %% [raw]
# Target Variable: The cardio column indicates whether a person has cardiovascular disease (1) or not (0). This is the target variable for predictive analysis.
#
# Potential Risk Factors: Age, blood pressure, cholesterol, glucose levels, smoking, alcohol consumption, and physical activity are all known contributors to cardiovascular disease.
#
# Binary & Categorical Data: Variables like gender, cholesterol, gluc, smoke, alco, active, and cardio are categorical/binary, which will require appropriate handling (e.g., encoding) in a predictive model.
#
# Continuous Data: Variables like age, height, weight, ap_hi, and ap_lo are continuous and might need scaling or normalization.

# %%
df.isnull().sum()
# Out:
# id             0
#  age           0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
#  gluc          0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# id             0
#  age           0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
#  gluc          0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', ' age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', ' gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  ' age',
#  'gender',
#  'height',
#  'weight',
#  'ap_hi',
#  'ap_lo',
#  'cholesterol',
#  ' gluc',
#  'smoke',
#  'alco',
#  'active',
#  'cardio']

# %%
df.dtypes
# Out:
# id               int64
#  age             int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
#  gluc            int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
#to view basic statistics
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean   49971.705224  19468.850512      1.349576    164.359148     74.205722
# std    28850.888785   2467.265969      0.476840      8.210157     14.395857
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.500000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.000000  19703.000000      1.000000    165.000000     72.000000
# 75%    74887.500000  21327.000000      2.000000    170.000000     82.000000
# max    99998.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean     128.817412     96.630652      1.366862      1.226460      0.088130
# ...

# %%
#get a count of no of patients with cadiovascular diseases
df['cardio'].value_counts()
# Out:
# cardio
# 0    35020
# 1    34979
# Name: count, dtype: int64

# %% [markdown]
# 0 indicates that the person is free from the  diseases
#
# 1 indicates that the person is suffering from diseases

# %%
#visualize the count
sns.countplot(df['cardio'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Age Distribution

# %% [raw]
# The goal of this analysis is to visualize the age distribution of individuals in the dataset to understand how age is spread across the population.
# We first convert the age data, which is given in days, into years by dividing the values by 365 (since there are 365 days in a year).
# Then, we use a histogram to visualize the distribution of ages, where the x-axis represents the age in years, and the y-axis shows the count of individuals in each age group.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert age from days to years (assuming 365 days per year)
df['age_years'] = df[' age'] / 365

# Age distribution
plt.figure(figsize=(8,6))
sns.histplot(df['age_years'], bins=10)
plt.title('Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Gender distribution

# %% [raw]
# This count plot shows the distribution of genders in the dataset.
# The x-axis represents gender (1 = Male, 2 = Female), while the y-axis shows the count of individuals in each category.
# It helps us understand whether the dataset is balanced in terms of gender, which is important for unbiased analysis of cardiovascular disease.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='gender', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender (1 = Male, 2 = Female)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Blood pressure (ap_hi and ap_lo) distribution

# %% [raw]
# # The x-axis represents blood pressure values, while the y-axis shows the count of individuals in each range.
# Helps detect potential outliers or unusual values in blood pressure, which are key factors for cardiovascular disease risk.

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
sns.histplot(df['ap_hi'], bins=10)
plt.title('Systolic Blood Pressure Distribution (ap_hi)')
plt.xlabel('ap_hi')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(1, 2, 2)
sns.histplot(df['ap_lo'], bins=10)
plt.title('Diastolic Blood Pressure Distribution (ap_lo)')
plt.xlabel('ap_lo')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Cholesterol distribution

# %% [raw]
# The x-axis represents three categories of cholesterol:
# 1 = Normal
# 2 = Above normal
# 3 = Well above normal
# The y-axis shows the number of individuals in each category, giving a sense of how cholesterol is distributed within the group.
# This visualization helps assess whether cholesterol is a significant risk factor in the population.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='cholesterol', data=df)
plt.title('Cholesterol Levels')
plt.xlabel('Cholesterol (1 = normal, 2 = above normal, 3 = well above normal)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Cardiovascular disease distribution

# %% [raw]
# The bar plot shows the distribution of individuals with and without cardiovascular disease.
# The x-axis represents the cardio variable:
# 0 = No Cardiovascular Disease
# 1 = Cardiovascular Disease
# The y-axis shows the number of individuals in each category.
# The plot shows nearly equal counts of individuals with and without cardiovascular disease, indicating a balanced dataset.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='cardio', data=df)
plt.title('Cardiovascular Disease Distribution')
plt.xlabel('Cardio (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Correlation matrix

# %% [raw]
# The correlation matrix shows relationships between variables. Positive correlations indicate both variables increase together.
#  Moderate correlations are seen between cardiovascular disease and factors like age, cholesterol, and systolic blood pressure, highlighting their importance for predicting disease risk.

# %%
# Correlation matrix
corr = df.corr()

# Heatmap for correlation
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# # DATA PREPARTION

# %% [markdown]
# # 1. Null Check

# %%
df.isnull().sum()
# Out:
# id             0
#  age           0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
#  gluc          0
# smoke          0
# alco           0
# active         0
# cardio         0
# age_years      0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['id', ' age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', ' gluc', 'smoke', 'alco', 'active', 'cardio',
#        'age_years'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id               int64
#  age             int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
#  gluc            int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# age_years      float64
# dtype: object

# %% [markdown]
# # 2. Converting age to years

# %%
#look at number of people with cardiovascular diseases that exceed the number of people without the cardiovascular diseases
#create a years column
df['years']=(df[' age']/365)

# %%
df['years']
# Out:
# 0        50.391781
# 1        55.419178
# 2        51.663014
# 3        48.282192
# 4        47.873973
#            ...
# 69994    57.736986
# 69995    52.712329
# 69996    61.920548
# 69997    52.235616
# 69998    61.454795
# Name: years, Length: 69999, dtype: float64

# %%
#rounding the vales of year column
df['years']=(df[' age']/365).round(0)

# %%
df['years']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69994    58.0
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# Name: years, Length: 69999, dtype: float64

# %% [markdown]
# # 3. Type Conversions

# %%
df['years'].dtypes
# Out:
# dtype('float64')

# %%
df['years']=pd.to_numeric(df['years'],downcast="integer")

# %%
df['years'].dtypes
# Out:
# dtype('int8')

# %%
#visualize the data
sns.countplot(x="years" , hue="cardio",data=df,palette="colorblind",edgecolor=sns.color_palette('dark',n_colors=1))
# Out:
# <Axes: xlabel='years', ylabel='count'>

# %% [markdown]
# before age 55 we observed that the number of persons with cardiovascular diseases are less than number of persons without cardiovascular diseases
#
# after age 55 we observed that the number of persons with cardiovascular diseases are more than number of persons without cardiovascular diseases

# %% [markdown]
# # 4. Removing Unnecessary Columns

# %%
#remove id column becoz it is 0% correlated with cardio
df=df.drop('id',axis=1)

# %%
print(df.columns)
# Out:
# Index([' age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        ' gluc', 'smoke', 'alco', 'active', 'cardio', 'age_years', 'years'],
#       dtype='object')

# %% [markdown]
# # RESULTS

# %% [raw]
# Age and Cardiovascular Disease: Most individuals are aged between 45 and 55, a group at higher risk for cardiovascular disease.
#
# Gender Distribution: The dataset has a slight male majority (55%), suggesting a need for gender-specific analysis of cardiovascular risk.
#
# Blood Pressure Levels: Elevated systolic (110–130 mmHg) and diastolic (70–90 mmHg) blood pressures are prevalent, indicating hypertension as a major risk factor.
#
# Cholesterol and Cardiovascular Risk: Although most have normal cholesterol, elevated cholesterol in a minority group increases the risk of cardiovascular disease.
#
# Lifestyle Factors: Smoking and alcohol consumption are rare, and a majority of individuals are physically active, which might reduce their risk.
#
# Correlation Insights: Age, blood pressure, and cholesterol showed strong correlations with cardiovascular disease, making them important predictors for modeling.

# %% [markdown]
# # Implications for Predictive Modeling:

# %% [raw]
# 1. The insights from EDA indicate that variables like age, blood pressure, cholesterol, and lifestyle factors (smoking, physical activity) will likely be strong predictors for cardiovascular disease.
#
# 2. Lifestyle interventions such as increasing physical activity, controlling cholesterol levels, and maintaining normal blood pressure will be crucial to managing cardiovascular disease risk.
#
# 3. Feature selection: Focusing on variables that show stronger correlations with cardiovascular disease (like blood pressure and cholesterol) may improve model performance.
#
# 4. Model Choice: Given the nature of the data and the binary target variable (cardio), models such as logistic regression, decision trees, or random forests can be applied for classification.
# By understanding the distributions and relationships between variables, we are better positioned to build a model that accurately predicts the likelihood of cardiovascular disease.

# %% [markdown]
# # Tools Used

# %% [raw]
# 1. Kaggle is a powerful platform that can support the analysis of datasets like the one used in this cardiovascular disease study.
#
# 2. DataCamp: An online learning platform offering interactive courses on data science, analytics, and machine learning using tools like Python and R.
#
# 3. ChatGPT: ChatGPT was leveraged to summarize the patterns and relationships identified through the visualizations and statistical measures, such as correlations between variables and their relevance to cardiovascular disease.
